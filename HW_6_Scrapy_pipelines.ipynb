# %% [markdown]
# #1) Взять любую категорию товаров на сайте Castorama. Собрать следующие данные:
# ###● название;
# ###● все фото;
# ###● ссылка;
# ###● цена.
#
# ###Реализуйте очистку и преобразование данных с помощью ItemLoader. Цены должны быть в виде числового значения.
#
# #Дополнительно:
# ###2)Написать универсальный обработчик характеристик товаров, который будет формировать данные вне зависимости от их типа и количества.
#
# ###3)Реализовать хранение скачиваемых файлов в отдельных папках, каждая из которых должна соответствовать собираемому товару

# %%
# !pip install scrapy

# %%
# !scrapy startproject goods_scraper
# Out:
# New Scrapy project 'goods_scraper', using template directory '/usr/local/lib/python3.7/dist-packages/scrapy/templates/project', created in:
#     /content/goods_scraper
#
# You can start your first spider with:
#     cd goods_scraper
#     scrapy genspider example example.com

# %%
cd goods_scraper/goods_scraper
# Out:
# /content/goods_scraper/goods_scraper

# %%
# !scrapy genspider castorama_ru castorama.ru
# Out:
# Created spider 'castorama_ru' using template 'basic' in module:
#   goods_scraper.spiders.castorama_ru

# %%
# !scrapy crawl castorama_ru
# Out:
# 2022-09-25 06:55:44 [scrapy.utils.log] INFO: Scrapy 2.6.2 started (bot: goods_scraper)
# 2022-09-25 06:55:44 [scrapy.utils.log] INFO: Versions: lxml 4.9.1.0, libxml2 2.9.14, cssselect 1.1.0, parsel 1.6.0, w3lib 2.0.1, Twisted 22.8.0, Python 3.7.14 (default, Sep  8 2022, 00:06:44) - [GCC 7.5.0], pyOpenSSL 22.0.0 (OpenSSL 3.0.5 5 Jul 2022), cryptography 38.0.1, Platform Linux-5.10.133+-x86_64-with-Ubuntu-18.04-bionic
# 2022-09-25 06:55:44 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'goods_scraper',
#  'CONCURRENT_REQUESTS': 1,
#  'DOWNLOAD_DELAY': 1.5,
#  'NEWSPIDER_MODULE': 'goods_scraper.spiders',
#  'SPIDER_MODULES': ['goods_scraper.spiders'],
#  'USER_AGENT': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 '
#                '(KHTML, like Gecko) Chrome/105.0.0.0 Safari/537.36 '
#                'Edg/105.0.1343.42'}
# 2022-09-25 06:55:44 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.epollreactor.EPollReactor
# 2022-09-25 06:55:44 [scrapy.extensions.telnet] INFO: Telnet Password: 0daa275533426208
# 2022-09-25 06:55:44 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2022-09-25 06:55:44 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2022-09-25 06:55:44 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2022-09-25 06:55:44 [scrapy.middleware] INFO: Enabled item pipelines:
# ['goods_scraper.pipelines.CastoramaPhotosPipeline',
#  'goods_scraper.pipelines.GoodsScraperPipeline']
# 2022-09-25 06:55:44 [scrapy.core.engine] INFO: Spider opened
# 2022-09-25 06:55:44 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2022-09-25 06:55:44 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2022-09-25 06:55:44 [filelock] DEBUG: Attempting to acquire lock 140151607526096 on /root/.cache/python-tldextract/3.7.14.final__usr__7d8fdf__tldextract-3.3.1/publicsuffix.org-tlds/de84b5ca2167d4c83e38fb162f2e8738.tldextract.json.lock
# 2022-09-25 06:55:44 [filelock] DEBUG: Lock 140151607526096 acquired on /root/.cache/python-tldextract/3.7.14.final__usr__7d8fdf__tldextract-3.3.1/publicsuffix.org-tlds/de84b5ca2167d4c83e38fb162f2e8738.tldextract.json.lock
# 2022-09-25 06:55:44 [filelock] DEBUG: Attempting to release lock 140151607526096 on /root/.cache/python-tldextract/3.7.14.final__usr__7d8fdf__tldextract-3.3.1/publicsuffix.org-tlds/de84b5ca2167d4c83e38fb162f2e8738.tldextract.json.lock
# 2022-09-25 06:55:44 [filelock] DEBUG: Lock 140151607526096 released on /root/.cache/python-tldextract/3.7.14.final__usr__7d8fdf__tldextract-3.3.1/publicsuffix.org-tlds/de84b5ca2167d4c83e38fb162f2e8738.tldextract.json.lock
# 2022-09-25 06:55:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.castorama.ru/heating-water-supply-and-ventilation/fireplaces/fireplace-sets> (referer: None)
# 2022-09-25 06:55:46 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.castorama.ru/jelektricheskij-kamin-real-flame-athena-25-25-5-wt-evrika> (referer: https://www.castorama.ru/heating-water-supply-and-ventilation/fireplaces/fireplace-sets)
# 2022-09-25 06:55:47 [scrapy.pipelines.files] DEBUG: File (uptodate): Downloaded image from <GET https://www.castorama.ru/media/catalog/product/cache/image/1800x/040ec09b1e35df139433887a97daa66f/c/4/c49ee9_593287_1.jpg> referred in <None>
# 2022-09-25 06:55:47 [scrapy.pipelines.files] DEBUG: File (uptodate): Downloaded image from <GET https://www.castorama.ru/media/catalog/product/cache/image/1800x/040ec09b1e35df139433887a97daa66f/b/9/b936a6_593287_2.jpg> referred in <None>
# 2022-09-25 06:55:47 [scrapy.pipelines.files] DEBUG: File (uptodate): Downloaded image from <GET https://www.castorama.ru/media/catalog/product/cache/image/1800x/040ec09b1e35df139433887a97daa66f/f/f/fffc78_593287_3.jpg> referred in <None>
# 2022-09-25 06:55:47 [scrapy.pipelines.files] DEBUG: File (uptodate): Downloaded image from <GET https://www.castorama.ru/media/catalog/product/cache/image/1800x/040ec09b1e35df139433887a97daa66f/6/6/668b7b_593287_4.jpg> referred in <None>
# 2022-09-25 06:55:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.castorama.ru/jelektricheskij-kamin-real-flame-athena-25-25-5-wt-evrika>
# {'name_goods': 'Электрический камин Real Flame Athena 25/25,5 WT+Evrika',
#  'photos': [{'checksum': '173576c772f27038bcdc5cab08df18cf',
#              'path': '593287/c49ee9_593287_1.jpg',
#              'status': 'uptodate',
#              'url': 'https://www.castorama.ru/media/catalog/product/cache/image/1800x/040ec09b1e35df139433887a97daa66f/c/4/c49ee9_593287_1.jpg'},
#             {'checksum': 'c490b9391228883ef20c5183971926e2',
#              'path': '593287/b936a6_593287_2.jpg',
#              'status': 'uptodate',
#              'url': 'https://www.castorama.ru/media/catalog/product/cache/image/1800x/040ec09b1e35df139433887a97daa66f/b/9/b936a6_593287_2.jpg'},
#             {'checksum': '241a18d1a5873a5749ba58f5dc7b6f1d',
#              'path': '593287/fffc78_593287_3.jpg',
#              'status': 'uptodate',
#              'url': 'https://www.castorama.ru/media/catalog/product/cache/image/1800x/040ec09b1e35df139433887a97daa66f/f/f/fffc78_593287_3.jpg'},
#             {'checksum': '3433dbc1b9fff6824b5a5335a56772a7',
#              'path': '593287/668b7b_593287_4.jpg',
#              'status': 'uptodate',
#              'url': 'https://www.castorama.ru/media/catalog/product/cache/image/1800x/040ec09b1e35df139433887a97daa66f/6/6/668b7b_593287_4.jpg'}],
#  'price': 48990.0,
#  'specifications': {'Артикул производителя': '10015022',
#                     'Бренд': 'Real Flame',
#                     'Вес, кг': '64',
#                     'Внимание': 'является технически сложным товаром, '
#                                 'пользуйтесь услугами квалифицированных '
#                                 'специалистов при подключении, наладке и пуске '
#                                 'в эксплуатацию',
#                     'Высота, см': '98.5',
#                     'Гарантия': '1 год',
#                     'Глубина, см': '40',
#                     'Декор очага': 'да',
#                     'Максимальный объем обогрева, м3': '54',
#                     'Материал': 'МДФ',
#                     'Напряжение, В': '220',
#                     'Нужен ли дымоход': 'нет',
#                     'Подсветка': 'да',
#                     'Размеры упаковки (ШхВхГ), см': '123 x 120.5 x 47.5',
#                     'Страна-производитель': 'Китай',
#                     'Тип продукта': 'Электрический камин',
#                     'Тип топки': 'закрытая',
#                     'Топка в комплекте': 'да',
#                     'Топливо': 'электричество',
#                     'Ширина, см': '108'},
#  'specifications_key': ['Тип продукта',
#                         'Артикул производителя',
#                         'Материал',
#                         'Тип топки',
#                         'Топка в комплекте',
#                         'Топливо',
#                         'Декор очага',
#                         'Подсветка',
#                         'Нужен ли дымоход',
#                         'Максимальный объем обогрева, м3',
#                         'Напряжение, В',
#                         'Ширина, см',
#                         'Высота, см',
#                         'Глубина, см',
#                         'Вес, кг',
#                         'Бренд',
#                         'Страна-производитель',
#                         'Гарантия',
#                         'Внимание',
#                         'Размеры упаковки (ШхВхГ), см'],
#  'specifications_value': ['Электрический камин',
#                           '10015022',
#                           'МДФ',
#                           'закрытая',
#                           'да',
#                           'электричество',
#                           'да',
#                           'да',
#                           'нет',
#                           '54',
#                           '220',
#                           '108',
#                           '98.5',
#                           '40',
#                           '64',
#                           'Real Flame',
#                           'Китай',
#                           '1 год',
#                           'является технически сложным товаром, пользуйтесь '
#                           'услугами квалифицированных специалистов при '
#                           'подключении, наладке и пуске в эксплуатацию',
#                           '123 x 120.5 x 47.5'],
#  'url': ['https://www.castorama.ru/jelektricheskij-kamin-real-flame-athena-25-25-5-wt-evrika']}
# 2022-09-25 06:55:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.castorama.ru/jelektroochag-real-flame-fobos-s-lux-bl> (referer: https://www.castorama.ru/heating-water-supply-and-ventilation/fireplaces/fireplace-sets)
# 2022-09-25 06:55:49 [scrapy.pipelines.files] DEBUG: File (uptodate): Downloaded image from <GET https://www.castorama.ru/media/catalog/product/cache/image/1800x/040ec09b1e35df139433887a97daa66f/7/e/7e8327_594892_1.jpg> referred in <None>
# 2022-09-25 06:55:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.castorama.ru/jelektroochag-real-flame-fobos-s-lux-bl>
# {'name_goods': 'Электроочаг Real Flame Fobos-S Lux BL',
#  'photos': [{'checksum': 'f738d8cf1ce86e115d94d276b085a0b0',
#              'path': '594892/7e8327_594892_1.jpg',
#              'status': 'uptodate',
#              'url': 'https://www.castorama.ru/media/catalog/product/cache/image/1800x/040ec09b1e35df139433887a97daa66f/7/e/7e8327_594892_1.jpg'}],
#  'price': 15990.0,
#  'specifications': {'Бренд': 'Real Flame',
#                     'Вес, кг': '13',
#                     'Внимание': 'является технически сложным товаром, '
#                                 'пользуйтесь услугами квалифицированных '
#                                 'специалистов при подключении, наладке и пуске '
#                                 'в эксплуатацию',
#                     'Высота, см': '61',
#                     'Гарантия': '1 год',
#                     'Глубина, см': '29',
#                     'Декор очага': 'да',
#                     'Дополнительная информация': 'общая мощность, Вт: 1600; '
#                                                  'мощность обогрева, Вт: 1500',
#                     'Максимальный объем обогрева, м3': '47',
#                     'Напряжение, В': '220',
#                     'Нужен ли дымоход': 'нет',
#                     'Освещение': 'нет',
#                     'Подсветка': 'нет',
#                     'Размеры упаковки (ШхВхГ), см': '55 x 65 x 35',
#                     'Страна-производитель': 'Китай',
#                     'Тип продукта': 'Электрический камин',
#                     'Тип топки': 'открытая',
#                     'Топка в комплекте': 'да',
#                     'Топливо': 'электричество',
#                     'Ширина, см': '50.3'},
#  'specifications_key': ['Тип продукта',
#                         'Тип топки',
#                         'Топка в комплекте',
#                         'Топливо',
#                         'Декор очага',
#                         'Освещение',
#                         'Подсветка',
#                         'Нужен ли дымоход',
#                         'Максимальный объем обогрева, м3',
#                         'Напряжение, В',
#                         'Ширина, см',
#                         'Высота, см',
#                         'Глубина, см',
#                         'Вес, кг',
#                         'Бренд',
#                         'Страна-производитель',
#                         'Дополнительная информация',
#                         'Гарантия',
#                         'Внимание',
#                         'Размеры упаковки (ШхВхГ), см'],
#  'specifications_value': ['Электрический камин',
#                           'открытая',
#                           'да',
#                           'электричество',
#                           'да',
#                           'нет',
#                           'нет',
#                           'нет',
#                           '47',
#                           '220',
#                           '50.3',
#                           '61',
#                           '29',
#                           '13',
#                           'Real Flame',
#                           'Китай',
#                           'общая мощность, Вт: 1600; мощность обогрева, Вт: '
#                           '1500',
#                           '1 год',
#                           'является технически сложным товаром, пользуйтесь '
#                           'услугами квалифицированных специалистов при '
#                           'подключении, наладке и пуске в эксплуатацию',
#                           '55 x 65 x 35'],
#  'url': ['https://www.castorama.ru/jelektroochag-real-flame-fobos-s-lux-bl']}
# 2022-09-25 06:55:51 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.castorama.ru/jelektricheskij-kamin-real-flame-evrika-25-5> (referer: https://www.castorama.ru/heating-water-supply-and-ventilation/fireplaces/fireplace-sets)
# 2022-09-25 06:55:51 [scrapy.pipelines.files] DEBUG: File (uptodate): Downloaded image from <GET https://www.castorama.ru/media/catalog/product/cache/image/1800x/040ec09b1e35df139433887a97daa66f/4/b/4b5560_594896_1.jpg> referred in <None>
# 2022-09-25 06:55:51 [scrapy.pipelines.files] DEBUG: File (uptodate): Downloaded image from <GET https://www.castorama.ru/media/catalog/product/cache/image/1800x/040ec09b1e35df139433887a97daa66f/8/9/89bf60_594896_3.jpg> referred in <None>
# 2022-09-25 06:55:51 [scrapy.pipelines.files] DEBUG: File (uptodate): Downloaded image from <GET https://www.castorama.ru/media/catalog/product/cache/image/1800x/040ec09b1e35df139433887a97daa66f/0/e/0e3bc4_594896_4.jpg> referred in <None>
# 2022-09-25 06:55:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.castorama.ru/jelektricheskij-kamin-real-flame-evrika-25-5>
# {'name_goods': 'Электрический камин Real Flame Evrika 25,5',
#  'photos': [{'checksum': '0b4701febcdf64c2d869d92e177d2edb',
#              'path': '594896/4b5560_594896_1.jpg',
#              'status': 'uptodate',
#              'url': 'https://www.castorama.ru/media/catalog/product/cache/image/1800x/040ec09b1e35df139433887a97daa66f/4/b/4b5560_594896_1.jpg'},
#             {'checksum': 'd4cdbb3bf1dd7178fe6cc5dfee7ba516',
#              'path': '594896/89bf60_594896_3.jpg',
#              'status': 'uptodate',
#              'url': 'https://www.castorama.ru/media/catalog/product/cache/image/1800x/040ec09b1e35df139433887a97daa66f/8/9/89bf60_594896_3.jpg'},
#             {'checksum': '24e015d29d719cb91c76ce67be1427b5',
#              'path': '594896/0e3bc4_594896_4.jpg',
#              'status': 'uptodate',
#              'url': 'https://www.castorama.ru/media/catalog/product/cache/image/1800x/040ec09b1e35df139433887a97daa66f/0/e/0e3bc4_594896_4.jpg'}],
#  'price': 22990.0,
#  'specifications': {'Бренд': 'Real Flame',
#                     'Вес, кг': '20',
#                     'Внимание': 'является технически сложным товаром, '
#                                 'пользуйтесь услугами квалифицированных '
#                                 'специалистов при подключении, наладке и пуске '
#                                 'в эксплуатацию',
#                     'Высота, см': '52.2',
#                     'Гарантия': '1 год',
#                     'Глубина, см': '21.5',
#                     'Декор очага': 'да',
#                     'Максимальный объем обогрева, м3': '54',
#                     'Модель': 'ch-720',
#                     'Напряжение, В': '220',
#                     'Нужен ли дымоход': 'нет',
#                     'Освещение': 'нет',
#                     'Подсветка': 'нет',
#                     'Размеры упаковки (ШхВхГ), см': '73 x 55 x 30',
#                     'Страна-производитель': 'Китай',
#                     'Тип продукта': 'Электрический камин',
#                     'Тип топки': 'закрытая',
#                     'Топка в комплекте': 'да',
#                     'Топливо': 'электричество',
#                     'Ширина, см': '68.9'},
#  'specifications_key': ['Тип продукта',
#                         'Тип топки',
#                         'Топка в комплекте',
#                         'Топливо',
#                         'Модель',
#                         'Декор очага',
#                         'Освещение',
#                         'Подсветка',
#                         'Нужен ли дымоход',
#                         'Максимальный объем обогрева, м3',
#                         'Напряжение, В',
#                         'Ширина, см',
#                         'Высота, см',
#                         'Глубина, см',
#                         'Вес, кг',
#                         'Бренд',
#                         'Страна-производитель',
#                         'Гарантия',
#                         'Внимание',
#                         'Размеры упаковки (ШхВхГ), см'],
#  'specifications_value': ['Электрический камин',
#                           'закрытая',
#                           'да',
#                           'электричество',
#                           'ch-720',
#                           'да',
#                           'нет',
#                           'нет',
#                           'нет',
#                           '54',
#                           '220',
#                           '68.9',
#                           '52.2',
#                           '21.5',
#                           '20',
#                           'Real Flame',
#                           'Китай',
#                           '1 год',
#                           'является технически сложным товаром, пользуйтесь '
#                           'услугами квалифицированных специалистов при '
#                           'подключении, наладке и пуске в эксплуатацию',
#                           '73 x 55 x 30'],
#  'url': ['https://www.castorama.ru/jelektricheskij-kamin-real-flame-evrika-25-5']}
# 2022-09-25 06:55:53 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.castorama.ru/jelektricheskij-kamin-real-flame-sparta-25-5> (referer: https://www.castorama.ru/heating-water-supply-and-ventilation/fireplaces/fireplace-sets)
# 2022-09-25 06:55:53 [scrapy.pipelines.files] DEBUG: File (uptodate): Downloaded image from <GET https://www.castorama.ru/media/catalog/product/cache/image/1800x/040ec09b1e35df139433887a97daa66f/6/7/67ee70_594895_1.jpg> referred in <None>
# 2022-09-25 06:55:53 [scrapy.pipelines.files] DEBUG: File (uptodate): Downloaded image from <GET https://www.castorama.ru/media/catalog/product/cache/image/1800x/040ec09b1e35df139433887a97daa66f/c/1/c1426e_594895_2.jpg> referred in <None>
# 2022-09-25 06:55:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.castorama.ru/jelektricheskij-kamin-real-flame-sparta-25-5>
# {'name_goods': 'Электрический камин Real Flame Sparta 25,5',
#  'photos': [{'checksum': '19dfe9c49a654ee218b9ee564f1e6b45',
#              'path': '594895/67ee70_594895_1.jpg',
#              'status': 'uptodate',
#              'url': 'https://www.castorama.ru/media/catalog/product/cache/image/1800x/040ec09b1e35df139433887a97daa66f/6/7/67ee70_594895_1.jpg'},
#             {'checksum': 'dec71d8f78f00b7efb3cb7852f3fa2be',
#              'path': '594895/c1426e_594895_2.jpg',
#              'status': 'uptodate',
#              'url': 'https://www.castorama.ru/media/catalog/product/cache/image/1800x/040ec09b1e35df139433887a97daa66f/c/1/c1426e_594895_2.jpg'}],
#  'price': 22990.0,
#  'specifications': {'Бренд': 'Real Flame',
#                     'Вес, кг': '20',
#                     'Внимание': 'является технически сложным товаром, '
#                                 'пользуйтесь услугами квалифицированных '
#                                 'специалистов при подключении, наладке и пуске '
#                                 'в эксплуатацию',
#                     'Высота, см': '68.9',
#                     'Гарантия': '1 год',
#                     'Глубина, см': '17',
#                     'Декор очага': 'да',
#                     'Максимальный объем обогрева, м3': '54',
#                     'Модель': 'ch-721',
#                     'Напряжение, В': '220',
#                     'Нужен ли дымоход': 'нет',
#                     'Освещение': 'нет',
#                     'Подсветка': 'нет',
#                     'Размеры упаковки (ШхВхГ), см': '73 x 55 x 25',
#                     'Страна-производитель': 'Китай',
#                     'Тип продукта': 'Электрический камин',
#                     'Тип топки': 'закрытая',
#                     'Топка в комплекте': 'да',
#                     'Топливо': 'электричество',
#                     'Ширина, см': '68.9'},
#  'specifications_key': ['Тип продукта',
#                         'Тип топки',
#                         'Топка в комплекте',
#                         'Топливо',
#                         'Модель',
#                         'Декор очага',
#                         'Освещение',
#                         'Подсветка',
#                         'Нужен ли дымоход',
#                         'Максимальный объем обогрева, м3',
#                         'Напряжение, В',
#                         'Ширина, см',
#                         'Высота, см',
#                         'Глубина, см',
#                         'Вес, кг',
#                         'Бренд',
#                         'Страна-производитель',
#                         'Гарантия',
#                         'Внимание',
#                         'Размеры упаковки (ШхВхГ), см'],
#  'specifications_value': ['Электрический камин',
#                           'закрытая',
#                           'да',
#                           'электричество',
#                           'ch-721',
#                           'да',
#                           'нет',
#                           'нет',
#                           'нет',
#                           '54',
#                           '220',
#                           '68.9',
#                           '68.9',
#                           '17',
#                           '20',
#                           'Real Flame',
#                           'Китай',
#                           '1 год',
#                           'является технически сложным товаром, пользуйтесь '
#                           'услугами квалифицированных специалистов при '
#                           'подключении, наладке и пуске в эксплуатацию',
#                           '73 x 55 x 25'],
#  'url': ['https://www.castorama.ru/jelektricheskij-kamin-real-flame-sparta-25-5']}
# 2022-09-25 06:55:55 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.castorama.ru/jelektricheskij-kamin-real-flame-kendal-s-24-1-8-kvt> (referer: https://www.castorama.ru/heating-water-supply-and-ventilation/fireplaces/fireplace-sets)
# 2022-09-25 06:55:55 [scrapy.pipelines.files] DEBUG: File (uptodate): Downloaded image from <GET https://www.castorama.ru/media/catalog/product/cache/image/1800x/040ec09b1e35df139433887a97daa66f/7/c/7c8945_594894_1.jpg> referred in <None>
# 2022-09-25 06:55:55 [scrapy.pipelines.files] DEBUG: File (uptodate): Downloaded image from <GET https://www.castorama.ru/media/catalog/product/cache/image/1800x/040ec09b1e35df139433887a97daa66f/e/b/ebe139_594894_2.jpg> referred in <None>
# 2022-09-25 06:55:55 [scrapy.pipelines.files] DEBUG: File (uptodate): Downloaded image from <GET https://www.castorama.ru/media/catalog/product/cache/image/1800x/040ec09b1e35df139433887a97daa66f/2/9/296036_594894_3.jpg> referred in <None>
# 2022-09-25 06:55:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.castorama.ru/jelektricheskij-kamin-real-flame-kendal-s-24-1-8-kvt>
# {'name_goods': 'Электрический камин Real Flame Kendal-S 24, 1,8 кВт',
#  'photos': [{'checksum': 'c6b3ca35649d7c1bd2aaa6483617a48e',
#              'path': '594894/7c8945_594894_1.jpg',
#              'status': 'uptodate',
#              'url': 'https://www.castorama.ru/media/catalog/product/cache/image/1800x/040ec09b1e35df139433887a97daa66f/7/c/7c8945_594894_1.jpg'},
#             {'checksum': 'b1af9534dca3283d924272ddaa200056',
#              'path': '594894/ebe139_594894_2.jpg',
#              'status': 'uptodate',
#              'url': 'https://www.castorama.ru/media/catalog/product/cache/image/1800x/040ec09b1e35df139433887a97daa66f/e/b/ebe139_594894_2.jpg'},
#             {'checksum': 'e53dc99702a36089f66f046599dfeec8',
#              'path': '594894/296036_594894_3.jpg',
#              'status': 'uptodate',
#              'url': 'https://www.castorama.ru/media/catalog/product/cache/image/1800x/040ec09b1e35df139433887a97daa66f/2/9/296036_594894_3.jpg'}],
#  'price': 20990.0,
#  'specifications': {'Бренд': 'Real Flame',
#                     'Вес, кг': '15',
#                     'Внимание': 'является технически сложным товаром, '
#                                 'пользуйтесь услугами квалифицированных '
#                                 'специалистов при подключении, наладке и пуске '
#                                 'в эксплуатацию',
#                     'Высота, см': '43.5',
#                     'Гарантия': '1 год',
#                     'Глубина, см': '12',
#                     'Декор очага': 'да',
#                     'Максимальный объем обогрева, м3': '45',
#                     'Модель': 'kl77',
#                     'Мощность, кВт': '1.8',
#                     'Напряжение, В': '220',
#                     'Нужен ли дымоход': 'нет',
#                     'Освещение': 'нет',
#                     'Подсветка': 'нет',
#                     'Размеры упаковки (ШхВхГ), см': '67 x 50 x 20',
#                     'Страна-производитель': 'Китай',
#                     'Тип продукта': 'Электрический камин',
#                     'Тип топки': 'закрытая',
#                     'Топка в комплекте': 'да',
#                     'Топливо': 'электричество',
#                     'Ширина, см': '58.5'},
#  'specifications_key': ['Тип продукта',
#                         'Тип топки',
#                         'Топка в комплекте',
#                         'Топливо',
#                         'Модель',
#                         'Декор очага',
#                         'Освещение',
#                         'Подсветка',
#                         'Нужен ли дымоход',
#                         'Мощность, кВт',
#                         'Максимальный объем обогрева, м3',
#                         'Напряжение, В',
#                         'Ширина, см',
#                         'Высота, см',
#                         'Глубина, см',
#                         'Вес, кг',
#                         'Бренд',
#                         'Страна-производитель',
#                         'Гарантия',
#                         'Внимание',
#                         'Размеры упаковки (ШхВхГ), см'],
#  'specifications_value': ['Электрический камин',
#                           'закрытая',
#                           'да',
#                           'электричество',
#                           'kl77',
#                           'да',
#                           'нет',
#                           'нет',
#                           'нет',
#                           '1.8',
#                           '45',
#                           '220',
#                           '58.5',
#                           '43.5',
#                           '12',
#                           '15',
#                           'Real Flame',
#                           'Китай',
#                           '1 год',
#                           'является технически сложным товаром, пользуйтесь '
#                           'услугами квалифицированных специалистов при '
#                           'подключении, наладке и пуске в эксплуатацию',
#                           '67 x 50 x 20'],
#  'url': ['https://www.castorama.ru/jelektricheskij-kamin-real-flame-kendal-s-24-1-8-kvt']}
# 2022-09-25 06:55:57 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.castorama.ru/jelektricheskij-kamin-real-flame-kellie-25-5-26-wt-sparta> (referer: https://www.castorama.ru/heating-water-supply-and-ventilation/fireplaces/fireplace-sets)
# 2022-09-25 06:55:57 [scrapy.pipelines.files] DEBUG: File (uptodate): Downloaded image from <GET https://www.castorama.ru/media/catalog/product/cache/image/1800x/040ec09b1e35df139433887a97daa66f/5/b/5b008a_593286_1.jpg> referred in <None>
# 2022-09-25 06:55:57 [scrapy.pipelines.files] DEBUG: File (uptodate): Downloaded image from <GET https://www.castorama.ru/media/catalog/product/cache/image/1800x/040ec09b1e35df139433887a97daa66f/b/7/b7b7a5_593286_2.jpg> referred in <None>
# 2022-09-25 06:55:57 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.castorama.ru/jelektricheskij-kamin-real-flame-kellie-25-5-26-wt-sparta>
# {'name_goods': 'Электрический камин Real Flame Kellie 25,5/26 WT+Sparta',
#  'photos': [{'checksum': 'cefe19040f9336a77d27a5a060b6ff99',
#              'path': '593286/5b008a_593286_1.jpg',
#              'status': 'uptodate',
#              'url': 'https://www.castorama.ru/media/catalog/product/cache/image/1800x/040ec09b1e35df139433887a97daa66f/5/b/5b008a_593286_1.jpg'},
#             {'checksum': 'b9d128ff6993e58093a3b52955d49019',
#              'path': '593286/b7b7a5_593286_2.jpg',
#              'status': 'uptodate',
#              'url': 'https://www.castorama.ru/media/catalog/product/cache/image/1800x/040ec09b1e35df139433887a97daa66f/b/7/b7b7a5_593286_2.jpg'}],
#  'price': 51990.0,
#  'specifications': {'Артикул производителя': '10015397',
#                     'Бренд': 'Real Flame',
#                     'Вес, кг': '72',
#                     'Внимание': 'является технически сложным товаром, '
#                                 'пользуйтесь услугами квалифицированных '
#                                 'специалистов при подключении, наладке и пуске '
#                                 'в эксплуатацию',
#                     'Высота, см': '95',
#                     'Гарантия': '1 год',
#                     'Глубина, см': '40',
#                     'Декор очага': 'да',
#                     'Максимальный объем обогрева, м3': '54',
#                     'Материал': 'МДФ',
#                     'Напряжение, В': '220',
#                     'Нужен ли дымоход': 'нет',
#                     'Подсветка': 'да',
#                     'Размеры упаковки (ШхВхГ), см': '134.5 x 113 x 46',
#                     'Страна-производитель': 'Китай',
#                     'Тип продукта': 'Электрический камин',
#                     'Тип топки': 'закрытая',
#                     'Топка в комплекте': 'да',
#                     'Топливо': 'электричество',
#                     'Ширина, см': '118'},
#  'specifications_key': ['Тип продукта',
#                         'Артикул производителя',
#                         'Материал',
#                         'Тип топки',
#                         'Топка в комплекте',
#                         'Топливо',
#                         'Декор очага',
#                         'Подсветка',
#                         'Нужен ли дымоход',
#                         'Максимальный объем обогрева, м3',
#                         'Напряжение, В',
#                         'Ширина, см',
#                         'Высота, см',
#                         'Глубина, см',
#                         'Вес, кг',
#                         'Бренд',
#                         'Страна-производитель',
#                         'Гарантия',
#                         'Внимание',
#                         'Размеры упаковки (ШхВхГ), см'],
#  'specifications_value': ['Электрический камин',
#                           '10015397',
#                           'МДФ',
#                           'закрытая',
#                           'да',
#                           'электричество',
#                           'да',
#                           'да',
#                           'нет',
#                           '54',
#                           '220',
#                           '118',
#                           '95',
#                           '40',
#                           '72',
#                           'Real Flame',
#                           'Китай',
#                           '1 год',
#                           'является технически сложным товаром, пользуйтесь '
#                           'услугами квалифицированных специалистов при '
#                           'подключении, наладке и пуске в эксплуатацию',
#                           '134.5 x 113 x 46'],
#  'url': ['https://www.castorama.ru/jelektricheskij-kamin-real-flame-kellie-25-5-26-wt-sparta']}
# 2022-09-25 06:55:59 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.castorama.ru/jelektricheskij-kamin-real-flame-neapolis-std-eug-wt-fobos-bl> (referer: https://www.castorama.ru/heating-water-supply-and-ventilation/fireplaces/fireplace-sets)
# 2022-09-25 06:55:59 [scrapy.pipelines.files] DEBUG: File (uptodate): Downloaded image from <GET https://www.castorama.ru/media/catalog/product/cache/image/1800x/040ec09b1e35df139433887a97daa66f/e/e/ee50e0_593285_1.jpg> referred in <None>
# 2022-09-25 06:55:59 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.castorama.ru/jelektricheskij-kamin-real-flame-neapolis-std-eug-wt-fobos-bl>
# {'name_goods': 'Электрический камин Real Flame Neapolis STD/EUG WT+Fobos bl',
#  'photos': [{'checksum': '1c19ccd506410a0c31b07f8feee069bf',
#              'path': '593285/ee50e0_593285_1.jpg',
#              'status': 'uptodate',
#              'url': 'https://www.castorama.ru/media/catalog/product/cache/image/1800x/040ec09b1e35df139433887a97daa66f/e/e/ee50e0_593285_1.jpg'}],
#  'price': 39990.0,
#  'specifications': {'Артикул производителя': '10019810',
#                     'Бренд': 'Real Flame',
#                     'Вес, кг': '84',
#                     'Внимание': 'является технически сложным товаром, '
#                                 'пользуйтесь услугами квалифицированных '
#                                 'специалистов при подключении, наладке и пуске '
#                                 'в эксплуатацию',
#                     'Высота, см': '97',
#                     'Гарантия': '1 год',
#                     'Глубина, см': '37',
#                     'Декор очага': 'да',
#                     'Максимальный объем обогрева, м3': '47',
#                     'Материал': 'МДФ',
#                     'Напряжение, В': '220',
#                     'Нужен ли дымоход': 'нет',
#                     'Подсветка': 'да',
#                     'Размеры упаковки (ШхВхГ), см': '116 x 120 x 46',
#                     'Страна-производитель': 'Китай',
#                     'Тип продукта': 'Электрический камин',
#                     'Тип топки': 'закрытая',
#                     'Топка в комплекте': 'да',
#                     'Топливо': 'электричество',
#                     'Ширина, см': '104'},
#  'specifications_key': ['Тип продукта',
#                         'Артикул производителя',
#                         'Материал',
#                         'Тип топки',
#                         'Топка в комплекте',
#                         'Топливо',
#                         'Декор очага',
#                         'Подсветка',
#                         'Нужен ли дымоход',
#                         'Максимальный объем обогрева, м3',
#                         'Напряжение, В',
#                         'Ширина, см',
#                         'Высота, см',
#                         'Глубина, см',
#                         'Вес, кг',
#                         'Бренд',
#                         'Страна-производитель',
#                         'Гарантия',
#                         'Внимание',
#                         'Размеры упаковки (ШхВхГ), см'],
#  'specifications_value': ['Электрический камин',
#                           '10019810',
#                           'МДФ',
#                           'закрытая',
#                           'да',
#                           'электричество',
#                           'да',
#                           'да',
#                           'нет',
#                           '47',
#                           '220',
#                           '104',
#                           '97',
#                           '37',
#                           '84',
#                           'Real Flame',
#                           'Китай',
#                           '1 год',
#                           'является технически сложным товаром, пользуйтесь '
#                           'услугами квалифицированных специалистов при '
#                           'подключении, наладке и пуске в эксплуатацию',
#                           '116 x 120 x 46'],
#  'url': ['https://www.castorama.ru/jelektricheskij-kamin-real-flame-neapolis-std-eug-wt-fobos-bl']}
# 2022-09-25 06:56:01 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.castorama.ru/jelektricheskij-kamin-real-flame-philadelphia25-5-26dn-sparta> (referer: https://www.castorama.ru/heating-water-supply-and-ventilation/fireplaces/fireplace-sets)
# 2022-09-25 06:56:01 [scrapy.pipelines.files] DEBUG: File (uptodate): Downloaded image from <GET https://www.castorama.ru/media/catalog/product/cache/image/1800x/040ec09b1e35df139433887a97daa66f/7/5/750ce5_593284_1.jpg> referred in <None>
# 2022-09-25 06:56:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.castorama.ru/jelektricheskij-kamin-real-flame-philadelphia25-5-26dn-sparta>
# {'name_goods': 'Электрический камин Real Flame Philadelphia25,5/26DN+Sparta',
#  'photos': [{'checksum': 'f2ab57fa06721ce7c9e60c42a8e9e935',
#              'path': '593284/750ce5_593284_1.jpg',
#              'status': 'uptodate',
#              'url': 'https://www.castorama.ru/media/catalog/product/cache/image/1800x/040ec09b1e35df139433887a97daa66f/7/5/750ce5_593284_1.jpg'}],
#  'price': 48990.0,
#  'specifications': {'Артикул производителя': '10014411',
#                     'Бренд': 'Real Flame',
#                     'Вес, кг': '54',
#                     'Внимание': 'является технически сложным товаром, '
#                                 'пользуйтесь услугами квалифицированных '
#                                 'специалистов при подключении, наладке и пуске '
#                                 'в эксплуатацию',
#                     'Высота, см': '99',
#                     'Гарантия': '1 год',
#                     'Глубина, см': '33',
#                     'Декор очага': 'да',
#                     'Максимальный объем обогрева, м3': '54',
#                     'Материал': 'МДФ',
#                     'Напряжение, В': '220',
#                     'Нужен ли дымоход': 'нет',
#                     'Подсветка': 'да',
#                     'Размеры упаковки (ШхВхГ), см': '122 x 46 x 38',
#                     'Страна-производитель': 'Китай',
#                     'Тип продукта': 'Электрический камин',
#                     'Тип топки': 'закрытая',
#                     'Топка в комплекте': 'да',
#                     'Топливо': 'электричество',
#                     'Ширина, см': '116'},
#  'specifications_key': ['Тип продукта',
#                         'Артикул производителя',
#                         'Материал',
#                         'Тип топки',
#                         'Топка в комплекте',
#                         'Топливо',
#                         'Декор очага',
#                         'Подсветка',
#                         'Нужен ли дымоход',
#                         'Максимальный объем обогрева, м3',
#                         'Напряжение, В',
#                         'Ширина, см',
#                         'Высота, см',
#                         'Глубина, см',
#                         'Вес, кг',
#                         'Бренд',
#                         'Страна-производитель',
#                         'Гарантия',
#                         'Внимание',
#                         'Размеры упаковки (ШхВхГ), см'],
#  'specifications_value': ['Электрический камин',
#                           '10014411',
#                           'МДФ',
#                           'закрытая',
#                           'да',
#                           'электричество',
#                           'да',
#                           'да',
#                           'нет',
#                           '54',
#                           '220',
#                           '116',
#                           '99',
#                           '33',
#                           '54',
#                           'Real Flame',
#                           'Китай',
#                           '1 год',
#                           'является технически сложным товаром, пользуйтесь '
#                           'услугами квалифицированных специалистов при '
#                           'подключении, наладке и пуске в эксплуатацию',
#                           '122 x 46 x 38'],
#  'url': ['https://www.castorama.ru/jelektricheskij-kamin-real-flame-philadelphia25-5-26dn-sparta']}
# 2022-09-25 06:56:03 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.castorama.ru/jelektricheskij-kamin-real-flame-ottawa-std-eug-wt-fobos-bl> (referer: https://www.castorama.ru/heating-water-supply-and-ventilation/fireplaces/fireplace-sets)
# 2022-09-25 06:56:03 [scrapy.pipelines.files] DEBUG: File (uptodate): Downloaded image from <GET https://www.castorama.ru/media/catalog/product/cache/image/1800x/040ec09b1e35df139433887a97daa66f/7/6/76fc47_593283_1.jpg> referred in <None>
# 2022-09-25 06:56:03 [scrapy.pipelines.files] DEBUG: File (uptodate): Downloaded image from <GET https://www.castorama.ru/media/catalog/product/cache/image/1800x/040ec09b1e35df139433887a97daa66f/a/d/adcd40_593283_2.jpg> referred in <None>
# 2022-09-25 06:56:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.castorama.ru/jelektricheskij-kamin-real-flame-ottawa-std-eug-wt-fobos-bl>
# {'name_goods': 'Электрический камин Real Flame Ottawa STD/EUG WT+Fobos bl',
#  'photos': [{'checksum': '50feb8bde19ba45962b99cffdc0258de',
#              'path': '593283/76fc47_593283_1.jpg',
#              'status': 'uptodate',
#              'url': 'https://www.castorama.ru/media/catalog/product/cache/image/1800x/040ec09b1e35df139433887a97daa66f/7/6/76fc47_593283_1.jpg'},
#             {'checksum': '4601a2ca2470fded26a5b6f9a227edbc',
#              'path': '593283/adcd40_593283_2.jpg',
#              'status': 'uptodate',
#              'url': 'https://www.castorama.ru/media/catalog/product/cache/image/1800x/040ec09b1e35df139433887a97daa66f/a/d/adcd40_593283_2.jpg'}],
#  'price': 35990.0,
#  'specifications': {'Артикул производителя': '10018323',
#                     'Бренд': 'Real Flame',
#                     'Вес, кг': '48',
#                     'Внимание': 'является технически сложным товаром, '
#                                 'пользуйтесь услугами квалифицированных '
#                                 'специалистов при подключении, наладке и пуске '
#                                 'в эксплуатацию',
#                     'Высота, см': '96',
#                     'Гарантия': '1 год',
#                     'Глубина, см': '39',
#                     'Декор очага': 'да',
#                     'Максимальный объем обогрева, м3': '47',
#                     'Материал': 'МДФ',
#                     'Напряжение, В': '220',
#                     'Нужен ли дымоход': 'нет',
#                     'Подсветка': 'да',
#                     'Размеры упаковки (ШхВхГ), см': '105 x 35.5 x 43',
#                     'Страна-производитель': 'Китай',
#                     'Тип продукта': 'Электрический камин',
#                     'Тип топки': 'закрытая',
#                     'Топка в комплекте': 'да',
#                     'Топливо': 'электричество',
#                     'Ширина, см': '101'},
#  'specifications_key': ['Тип продукта',
#                         'Артикул производителя',
#                         'Материал',
#                         'Тип топки',
#                         'Топка в комплекте',
#                         'Топливо',
#                         'Декор очага',
#                         'Подсветка',
#                         'Нужен ли дымоход',
#                         'Максимальный объем обогрева, м3',
#                         'Напряжение, В',
#                         'Ширина, см',
#                         'Высота, см',
#                         'Глубина, см',
#                         'Вес, кг',
#                         'Бренд',
#                         'Страна-производитель',
#                         'Гарантия',
#                         'Внимание',
#                         'Размеры упаковки (ШхВхГ), см'],
#  'specifications_value': ['Электрический камин',
#                           '10018323',
#                           'МДФ',
#                           'закрытая',
#                           'да',
#                           'электричество',
#                           'да',
#                           'да',
#                           'нет',
#                           '47',
#                           '220',
#                           '101',
#                           '96',
#                           '39',
#                           '48',
#                           'Real Flame',
#                           'Китай',
#                           '1 год',
#                           'является технически сложным товаром, пользуйтесь '
#                           'услугами квалифицированных специалистов при '
#                           'подключении, наладке и пуске в эксплуатацию',
#                           '105 x 35.5 x 43'],
#  'url': ['https://www.castorama.ru/jelektricheskij-kamin-real-flame-ottawa-std-eug-wt-fobos-bl']}
# 2022-09-25 06:56:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.castorama.ru/jelektricheskij-kamin-real-flame-alta24-kendal-kl77-1-8-kvt> (referer: https://www.castorama.ru/heating-water-supply-and-ventilation/fireplaces/fireplace-sets)
# 2022-09-25 06:56:05 [scrapy.pipelines.files] DEBUG: File (uptodate): Downloaded image from <GET https://www.castorama.ru/media/catalog/product/cache/image/1800x/040ec09b1e35df139433887a97daa66f/c/6/c64f48_590690_1.jpg> referred in <None>
# 2022-09-25 06:56:05 [scrapy.pipelines.files] DEBUG: File (uptodate): Downloaded image from <GET https://www.castorama.ru/media/catalog/product/cache/image/1800x/040ec09b1e35df139433887a97daa66f/c/1/c1fc1d_590690_2.jpg> referred in <None>
# 2022-09-25 06:56:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.castorama.ru/jelektricheskij-kamin-real-flame-alta24-kendal-kl77-1-8-kvt>
# {'name_goods': 'Электрический камин Real Flame Alta24+Kendal (KL77), 1,8 кВт',
#  'photos': [{'checksum': 'c78ae308ac8ce275bb4594adbd617978',
#              'path': '590690/c64f48_590690_1.jpg',
#              'status': 'uptodate',
#              'url': 'https://www.castorama.ru/media/catalog/product/cache/image/1800x/040ec09b1e35df139433887a97daa66f/c/6/c64f48_590690_1.jpg'},
#             {'checksum': '09b4e5d899333b40e21104a68ae35d7d',
#              'path': '590690/c1fc1d_590690_2.jpg',
#              'status': 'uptodate',
#              'url': 'https://www.castorama.ru/media/catalog/product/cache/image/1800x/040ec09b1e35df139433887a97daa66f/c/1/c1fc1d_590690_2.jpg'}],
#  'price': 37990.0,
#  'specifications': {'Артикул производителя': 'Alta24+Kendal (KL77)',
#                     'Бренд': 'Real Flame',
#                     'Вес, кг': '55',
#                     'Внимание': 'является технически сложным товаром, '
#                                 'пользуйтесь услугами квалифицированных '
#                                 'специалистов при подключении, наладке и пуске '
#                                 'в эксплуатацию',
#                     'Высота, см': '83.5',
#                     'Гарантия': '1 год',
#                     'Глубина, см': '26',
#                     'Декор очага': 'да',
#                     'Максимальный объем обогрева, м3': '45',
#                     'Материал': 'МДФ',
#                     'Мощность, кВт': '1.8',
#                     'Напряжение, В': '220',
#                     'Нужен ли дымоход': 'нет',
#                     'Подсветка': 'нет',
#                     'Размеры упаковки (ШхВхГ), см': '102.5 x 105 x 35',
# ...
#                           'да',
#                           'нет',
#                           'нет',
#                           '1.8',
#                           '54',
#                           '220',
#                           '104',
#                           '97',
#                           '37',
#                           '94',
#                           'Real Flame',
#                           'Китай',
#                           '1 год',
#                           'является технически сложным товаром, пользуйтесь '
#                           'услугами квалифицированных специалистов при '
#                           'подключении, наладке и пуске в эксплуатацию',
#                           '118 x 116 x 44.8'],
#  'url': ['https://www.castorama.ru/jelektricheskij-kamin-real-flame-dublin-rock-ao-majestic-1-8-kvt']}
# 2022-09-25 06:56:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.castorama.ru/jelektricheskij-kamin-real-flame-carolinawt-evrikach-720-1-8-kvt> (referer: https://www.castorama.ru/heating-water-supply-and-ventilation/fireplaces/fireplace-sets)
# 2022-09-25 06:56:09 [scrapy.pipelines.files] DEBUG: File (uptodate): Downloaded image from <GET https://www.castorama.ru/media/catalog/product/cache/image/1800x/040ec09b1e35df139433887a97daa66f/9/a/9a03ce_590691_1.jpg> referred in <None>
# 2022-09-25 06:56:09 [scrapy.pipelines.files] DEBUG: File (uptodate): Downloaded image from <GET https://www.castorama.ru/media/catalog/product/cache/image/1800x/040ec09b1e35df139433887a97daa66f/0/6/06731f_590691_2.jpg> referred in <None>
# 2022-09-25 06:56:09 [scrapy.pipelines.files] DEBUG: File (uptodate): Downloaded image from <GET https://www.castorama.ru/media/catalog/product/cache/image/1800x/040ec09b1e35df139433887a97daa66f/7/0/708f06_590691_3.jpg> referred in <None>
# 2022-09-25 06:56:09 [scrapy.pipelines.files] DEBUG: File (uptodate): Downloaded image from <GET https://www.castorama.ru/media/catalog/product/cache/image/1800x/040ec09b1e35df139433887a97daa66f/f/2/f2eaa7_590691_4.jpg> referred in <None>
# 2022-09-25 06:56:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.castorama.ru/jelektricheskij-kamin-real-flame-carolinawt-evrikach-720-1-8-kvt>
# {'name_goods': 'Электрический камин Real Flame CarolinaWT+EvrikaCH-720, 1,8 '
#                'кВт',
#  'photos': [{'checksum': 'edb3b97a59f6e7660a6b1ce734f37109',
#              'path': '590691/9a03ce_590691_1.jpg',
#              'status': 'uptodate',
#              'url': 'https://www.castorama.ru/media/catalog/product/cache/image/1800x/040ec09b1e35df139433887a97daa66f/9/a/9a03ce_590691_1.jpg'},
#             {'checksum': '05316856074cef9466f17886e2bf94c3',
#              'path': '590691/06731f_590691_2.jpg',
#              'status': 'uptodate',
#              'url': 'https://www.castorama.ru/media/catalog/product/cache/image/1800x/040ec09b1e35df139433887a97daa66f/0/6/06731f_590691_2.jpg'},
#             {'checksum': '685244baaf2555ad199b8c1ac79b9c85',
#              'path': '590691/708f06_590691_3.jpg',
#              'status': 'uptodate',
#              'url': 'https://www.castorama.ru/media/catalog/product/cache/image/1800x/040ec09b1e35df139433887a97daa66f/7/0/708f06_590691_3.jpg'},
#             {'checksum': 'be1c4aaaa2592a09327302274071d158',
#              'path': '590691/f2eaa7_590691_4.jpg',
#              'status': 'uptodate',
#              'url': 'https://www.castorama.ru/media/catalog/product/cache/image/1800x/040ec09b1e35df139433887a97daa66f/f/2/f2eaa7_590691_4.jpg'}],
#  'price': 40990.0,
#  'specifications': {'Артикул производителя': 'CarolinaWT+EvrikaCH-720',
#                     'Бренд': 'Real Flame',
#                     'Вес, кг': '55',
#                     'Внимание': 'является технически сложным товаром, '
#                                 'пользуйтесь услугами квалифицированных '
#                                 'специалистов при подключении, наладке и пуске '
#                                 'в эксплуатацию',
#                     'Высота, см': '93.5',
#                     'Гарантия': '1 год',
#                     'Глубина, см': '37',
#                     'Декор очага': 'да',
#                     'Максимальный объем обогрева, м3': '54',
#                     'Материал': 'МДФ',
#                     'Мощность, кВт': '1.8',
#                     'Напряжение, В': '220',
#                     'Нужен ли дымоход': 'нет',
#                     'Подсветка': 'нет',
#                     'Размеры упаковки (ШхВхГ), см': '112.4 x 126 x 44',
#                     'Страна-производитель': 'Китай',
#                     'Тип продукта': 'Электрический камин',
#                     'Тип топки': 'закрытая',
#                     'Топка в комплекте': 'да',
#                     'Топливо': 'электричество',
#                     'Ширина, см': '115'},
#  'specifications_key': ['Тип продукта',
#                         'Артикул производителя',
#                         'Материал',
#                         'Тип топки',
#                         'Топка в комплекте',
#                         'Топливо',
#                         'Декор очага',
#                         'Подсветка',
#                         'Нужен ли дымоход',
#                         'Мощность, кВт',
#                         'Максимальный объем обогрева, м3',
#                         'Напряжение, В',
#                         'Ширина, см',
#                         'Высота, см',
#                         'Глубина, см',
#                         'Вес, кг',
#                         'Бренд',
#                         'Страна-производитель',
#                         'Гарантия',
#                         'Внимание',
#                         'Размеры упаковки (ШхВхГ), см'],
#  'specifications_value': ['Электрический камин',
#                           'CarolinaWT+EvrikaCH-720',
#                           'МДФ',
#                           'закрытая',
#                           'да',
#                           'электричество',
#                           'да',
#                           'нет',
#                           'нет',
#                           '1.8',
#                           '54',
#                           '220',
#                           '115',
#                           '93.5',
#                           '37',
#                           '55',
#                           'Real Flame',
#                           'Китай',
#                           '1 год',
#                           'является технически сложным товаром, пользуйтесь '
#                           'услугами квалифицированных специалистов при '
#                           'подключении, наладке и пуске в эксплуатацию',
#                           '112.4 x 126 x 44'],
#  'url': ['https://www.castorama.ru/jelektricheskij-kamin-real-flame-carolinawt-evrikach-720-1-8-kvt']}
# 2022-09-25 06:56:11 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.castorama.ru/jelektricheskij-kamin-engy-en-507-1-5-kvt> (referer: https://www.castorama.ru/heating-water-supply-and-ventilation/fireplaces/fireplace-sets)
# 2022-09-25 06:56:11 [scrapy.pipelines.files] DEBUG: File (uptodate): Downloaded image from <GET https://www.castorama.ru/media/catalog/product/cache/image/1800x/040ec09b1e35df139433887a97daa66f/e/b/ebcbd5_588952_1.jpg> referred in <None>
# 2022-09-25 06:56:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.castorama.ru/jelektricheskij-kamin-engy-en-507-1-5-kvt>
# {'name_goods': 'Электрический камин Engy EN-507, 1,5 кВт',
#  'photos': [{'checksum': 'c03b9382789b56e0d9c61fa826535f1c',
#              'path': '588952/ebcbd5_588952_1.jpg',
#              'status': 'uptodate',
#              'url': 'https://www.castorama.ru/media/catalog/product/cache/image/1800x/040ec09b1e35df139433887a97daa66f/e/b/ebcbd5_588952_1.jpg'}],
#  'price': 4990.0,
#  'specifications': {'Артикул производителя': '102943',
#                     'Бренд': 'Engy',
#                     'Вес, кг': '1.71',
#                     'Внимание': 'является технически сложным товаром, '
#                                 'пользуйтесь услугами квалифицированных '
#                                 'специалистов при подключении, наладке и пуске '
#                                 'в эксплуатацию',
#                     'Высота, см': '33.6',
#                     'Гарантия': '1 год',
#                     'Глубина, см': '16',
#                     'Дополнительная информация': 'материал: пластик, металл',
#                     'Максимальный объем обогрева, м3': '15',
#                     'Модель': 'EN-507',
#                     'Мощность, кВт': '1.5',
#                     'Напряжение, В': '220',
#                     'Нужен ли дымоход': 'нет',
#                     'Подсветка': 'да',
#                     'Размеры упаковки (ШхВхГ), см': '29 x 38.7 x 21.4',
#                     'Страна-производитель': 'Китай',
#                     'Тип продукта': 'Электрический камин',
#                     'Топка в комплекте': 'нет',
#                     'Топливо': 'электричество',
#                     'Ширина, см': '24'},
#  'specifications_key': ['Тип продукта',
#                         'Артикул производителя',
#                         'Топка в комплекте',
#                         'Топливо',
#                         'Модель',
#                         'Подсветка',
#                         'Нужен ли дымоход',
#                         'Мощность, кВт',
#                         'Максимальный объем обогрева, м3',
#                         'Напряжение, В',
#                         'Ширина, см',
#                         'Высота, см',
#                         'Глубина, см',
#                         'Вес, кг',
#                         'Бренд',
#                         'Страна-производитель',
#                         'Дополнительная информация',
#                         'Гарантия',
#                         'Внимание',
#                         'Размеры упаковки (ШхВхГ), см'],
#  'specifications_value': ['Электрический камин',
#                           '102943',
#                           'нет',
#                           'электричество',
#                           'EN-507',
#                           'да',
#                           'нет',
#                           '1.5',
#                           '15',
#                           '220',
#                           '24',
#                           '33.6',
#                           '16',
#                           '1.71',
#                           'Engy',
#                           'Китай',
#                           'материал: пластик, металл',
#                           '1 год',
#                           'является технически сложным товаром, пользуйтесь '
#                           'услугами квалифицированных специалистов при '
#                           'подключении, наладке и пуске в эксплуатацию',
#                           '29 x 38.7 x 21.4'],
#  'url': ['https://www.castorama.ru/jelektricheskij-kamin-engy-en-507-1-5-kvt']}
# 2022-09-25 06:56:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.castorama.ru/jelektricheskij-kamin-real-flame-lilian-std-eug-dn-fobos-1-2-kvt> (referer: https://www.castorama.ru/heating-water-supply-and-ventilation/fireplaces/fireplace-sets)
# 2022-09-25 06:56:12 [scrapy.pipelines.files] DEBUG: File (uptodate): Downloaded image from <GET https://www.castorama.ru/media/catalog/product/cache/image/1800x/040ec09b1e35df139433887a97daa66f/0/e/0e0af7_591108_1.jpg> referred in <None>
# 2022-09-25 06:56:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.castorama.ru/jelektricheskij-kamin-real-flame-lilian-std-eug-dn-fobos-1-2-kvt>
# {'name_goods': 'Электрический камин Real Flame Lilian STD/EUG DN+Fobos, 1,2 '
#                'кВт',
#  'photos': [{'checksum': '735e521ae2173b4d78f41ec4a29421db',
#              'path': '591108/0e0af7_591108_1.jpg',
#              'status': 'uptodate',
#              'url': 'https://www.castorama.ru/media/catalog/product/cache/image/1800x/040ec09b1e35df139433887a97daa66f/0/e/0e0af7_591108_1.jpg'}],
#  'price': 38990.0,
#  'specifications': {'Артикул производителя': 'Lilian STD/EUG DN + Fobos',
#                     'Бренд': 'Real Flame',
#                     'Вес, кг': '55',
#                     'Внимание': 'является технически сложным товаром, '
#                                 'пользуйтесь услугами квалифицированных '
#                                 'специалистов при подключении, наладке и пуске '
#                                 'в эксплуатацию',
#                     'Высота, см': '89',
#                     'Гарантия': '1 год',
#                     'Глубина, см': '36.5',
#                     'Декор очага': 'да',
#                     'Максимальный объем обогрева, м3': '47',
#                     'Материал': 'МДФ',
#                     'Мощность, кВт': '1.2',
#                     'Напряжение, В': '220',
#                     'Нужен ли дымоход': 'нет',
#                     'Подсветка': 'нет',
#                     'Размеры упаковки (ШхВхГ), см': '118 x 116 x 44',
#                     'Страна-производитель': 'Китай',
#                     'Тип продукта': 'Электрический камин',
#                     'Тип топки': 'открытая',
#                     'Топка в комплекте': 'да',
#                     'Топливо': 'электричество',
#                     'Ширина, см': '97'},
#  'specifications_key': ['Тип продукта',
#                         'Артикул производителя',
#                         'Материал',
#                         'Тип топки',
#                         'Топка в комплекте',
#                         'Топливо',
#                         'Декор очага',
#                         'Подсветка',
#                         'Нужен ли дымоход',
#                         'Мощность, кВт',
#                         'Максимальный объем обогрева, м3',
#                         'Напряжение, В',
#                         'Ширина, см',
#                         'Высота, см',
#                         'Глубина, см',
#                         'Вес, кг',
#                         'Бренд',
#                         'Страна-производитель',
#                         'Гарантия',
#                         'Внимание',
#                         'Размеры упаковки (ШхВхГ), см'],
#  'specifications_value': ['Электрический камин',
#                           'Lilian STD/EUG DN + Fobos',
#                           'МДФ',
#                           'открытая',
#                           'да',
#                           'электричество',
#                           'да',
#                           'нет',
#                           'нет',
#                           '1.2',
#                           '47',
#                           '220',
#                           '97',
#                           '89',
#                           '36.5',
#                           '55',
#                           'Real Flame',
#                           'Китай',
#                           '1 год',
#                           'является технически сложным товаром, пользуйтесь '
#                           'услугами квалифицированных специалистов при '
#                           'подключении, наладке и пуске в эксплуатацию',
#                           '118 x 116 x 44'],
#  'url': ['https://www.castorama.ru/jelektricheskij-kamin-real-flame-lilian-std-eug-dn-fobos-1-2-kvt']}
# 2022-09-25 06:56:12 [scrapy.core.engine] INFO: Closing spider (finished)
# 2022-09-25 06:56:12 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 10394,
#  'downloader/request_count': 15,
#  'downloader/request_method_count/GET': 15,
#  'downloader/response_bytes': 675591,
#  'downloader/response_count': 15,
#  'downloader/response_status_count/200': 15,
#  'elapsed_time_seconds': 28.588772,
#  'file_count': 29,
#  'file_status_count/uptodate': 29,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2022, 9, 25, 6, 56, 12, 895610),
#  'httpcompression/response_bytes': 3719447,
#  'httpcompression/response_count': 15,
#  'item_scraped_count': 14,
#  'log_count/DEBUG': 63,
#  'log_count/INFO': 10,
#  'memusage/max': 76566528,
#  'memusage/startup': 76566528,
#  'request_depth_max': 1,
#  'response_received_count': 15,
#  'scheduler/dequeued': 15,
#  'scheduler/dequeued/memory': 15,
#  'scheduler/enqueued': 15,
#  'scheduler/enqueued/memory': 15,
#  'start_time': datetime.datetime(2022, 9, 25, 6, 55, 44, 306838)}
# 2022-09-25 06:56:12 [scrapy.core.engine] INFO: Spider closed (finished)
